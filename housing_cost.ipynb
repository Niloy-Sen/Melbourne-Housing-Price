# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:\\Users\\hp\\Downloads\\house pricing\\train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.isnull(),yticklabels=False,cmap='coolwarm')

# %%
df.drop(['PoolQC','Fence','MiscFeature','Alley'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.isnull(),yticklabels=False,cmap='coolwarm')

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
df.drop('FireplaceQu',axis=1,inplace=True)

# %%
df.drop('LotFrontage',axis=1,inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.isnull(),yticklabels=False,cmap='coolwarm')

# %%
sns.jointplot(x='LotArea',y='SalePrice',data=df)

# %%
df.shape
# Out:
# (1460, 75)

# %%
df['Street'].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
df['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
df['LandSlope'].value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
empty= [col for col in df.columns if df[col].isnull().any()]

# %%
empty
# Out:
# ['MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
for col in empty:
    df[col].fillna(value=df[col].mode(),inplace=True)

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.isnull(),yticklabels=False,cmap='coolwarm')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df.columns.isnull().any()
# Out:
# False

# %%
from sklearn.impute import SimpleImputer

# %%
mod=SimpleImputer(strategy='most_frequent')

# %%
imputer_df=pd.DataFrame(mod.fit_transform(df))

# %%
imputer_df
# Out:
#         Id MSSubClass MSZoning LotArea Street LotShape LandContour Utilities  \
# 0        1         60       RL    8450   Pave      Reg         Lvl    AllPub
# 1        2         20       RL    9600   Pave      Reg         Lvl    AllPub
# 2        3         60       RL   11250   Pave      IR1         Lvl    AllPub
# 3        4         70       RL    9550   Pave      IR1         Lvl    AllPub
# 4        5         60       RL   14260   Pave      IR1         Lvl    AllPub
# ...    ...        ...      ...     ...    ...      ...         ...       ...
# 1455  1456         60       RL    7917   Pave      Reg         Lvl    AllPub
# 1456  1457         20       RL   13175   Pave      Reg         Lvl    AllPub
# 1457  1458         70       RL    9042   Pave      Reg         Lvl    AllPub
# 1458  1459         20       RL    9717   Pave      Reg         Lvl    AllPub
# 1459  1460         20       RL    9937   Pave      Reg         Lvl    AllPub
#
# ...

# %%
imputer_df.columns=df.columns

# %%
plt.figure(figsize=(40,30))
sns.heatmap(imputer_df.isnull(),yticklabels=False,cmap='coolwarm')

# %%
s = (df.dtypes == 'object')
object_cols = list(s[s].index)

# %%
object_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
for col in object_cols:
    imputer_df[col]=label.fit_transform(imputer_df[col])

# %%
imputer_df
# Out:
#         Id MSSubClass  MSZoning LotArea  Street  LotShape  LandContour  \
# 0        1         60         3    8450       1         3            3
# 1        2         20         3    9600       1         3            3
# 2        3         60         3   11250       1         0            3
# 3        4         70         3    9550       1         0            3
# 4        5         60         3   14260       1         0            3
# ...    ...        ...       ...     ...     ...       ...          ...
# 1455  1456         60         3    7917       1         3            3
# 1456  1457         20         3   13175       1         3            3
# 1457  1458         70         3    9042       1         3            3
# 1458  1459         20         3    9717       1         3            3
# 1459  1460         20         3    9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=200)

# %%
from sklearn.linear_model import LogisticRegression
lmod=LogisticRegression()

# %%
xtrain=imputer_df.drop('SalePrice',axis=1)

# %%
ytrain=imputer_df['SalePrice']

# %%
for col in xtrain.columns:
    xtrain[col]=xtrain[col].astype('int64')

# %%
xtrain
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0        1          60         3     8450       1         3            3
# 1        2          20         3     9600       1         3            3
# 2        3          60         3    11250       1         0            3
# 3        4          70         3     9550       1         0            3
# 4        5          60         3    14260       1         0            3
# ...    ...         ...       ...      ...     ...       ...          ...
# 1455  1456          60         3     7917       1         3            3
# 1456  1457          20         3    13175       1         3            3
# 1457  1458          70         3     9042       1         3            3
# 1458  1459          20         3     9717       1         3            3
# 1459  1460          20         3     9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
for col in xtrain.columns:
    print(xtrain[col].dtype)
# Out:
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64

# %%
ytrain=ytrain.astype('int64')

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
lmod.fit(xtrain,ytrain)
# Out:
# F:\c\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
testdf=pd.read_csv('C:\\Users\\hp\\Downloads\\house pricing\\test.csv')

# %%
testdf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(testdf.isnull(),yticklabels=False,cmap='coolwarm')

# %%
testdf.drop(['PoolQC','Fence','MiscFeature','Alley'],axis=1,inplace=True)

# %%
testdf.drop('FireplaceQu',axis=1,inplace=True)

# %%
testdf.drop('LotFrontage',axis=1,inplace=True)

# %%
plt.figure(figsize=(40,30))
sns.heatmap(testdf.isnull(),yticklabels=False,cmap='coolwarm')

# %%
imputer_testdf=pd.DataFrame(mod.fit_transform(testdf))

# %%
imputer_testdf
# Out:
#         Id MSSubClass  MSZoning LotArea  Street  LotShape  LandContour  \
# 0     1461         20         2   11622       1         3            3
# 1     1462         20         3   14267       1         0            3
# 2     1463         60         3   13830       1         0            3
# 3     1464         60         3    9978       1         0            3
# 4     1465        120         3    5005       1         0            1
# ...    ...        ...       ...     ...     ...       ...          ...
# 1454  2915        160         4    1936       1         3            3
# 1455  2916        160         4    1894       1         3            3
# 1456  2917         20         3   20000       1         3            3
# 1457  2918         85         3   10441       1         3            3
# 1458  2919         60         3    9627       1         3            3
#
#       Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(imputer_testdf.isnull(),yticklabels=False,cmap='coolwarm')

# %%
imputer_testdf.columns=testdf.columns

# %%
for col in object_cols:
    imputer_testdf[col]=label.fit_transform(imputer_testdf[col])

# %%
for col in imputer_testdf.columns:
    imputer_testdf[col].astype('int64')

# %%
predictions=rfc.predict(imputer_testdf)

# %%
predictions
# Out:
# array([110000, 151500, 175000, ..., 147500,  93500, 175000], dtype=int64)

# %%
pred=pd.DataFrame(predictions)

# %%
pred
# Out:
#            0
# 0     110000
# 1     151500
# 2     175000
# 3     175000
# 4     185000
# ...      ...
# 1454   75000
# 1455   83500
# 1456  147500
# 1457   93500
# 1458  175000
#
# [1459 rows x 1 columns]

# %%
ans=pd.DataFrame(imputer_testdf['Id'])

# %%
ans
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
ans=pd.concat([ans,pred],axis=1)

# %%
ans
# Out:
#         Id       0
# 0     1461  110000
# 1     1462  151500
# 2     1463  175000
# 3     1464  175000
# 4     1465  185000
# ...    ...     ...
# 1454  2915   75000
# 1455  2916   83500
# 1456  2917  147500
# 1457  2918   93500
# 1458  2919  175000
#
# [1459 rows x 2 columns]

# %%
ans.columns=['Id','SalePrice']

# %%
ans
# Out:
#         Id  SalePrice
# 0     1461     110000
# 1     1462     151500
# 2     1463     175000
# 3     1464     175000
# 4     1465     185000
# ...    ...        ...
# 1454  2915      75000
# 1455  2916      83500
# 1456  2917     147500
# 1457  2918      93500
# 1458  2919     175000
#
# [1459 rows x 2 columns]

# %%
finalsub=ans.to_csv('answer.csv',index=False)

# %%
prediction2=lmod.predict(imputer_testdf)

# %%
pred2=pd.DataFrame(prediction2)

# %%
pred2
# Out:
#            0
# 0     145000
# 1     151500
# 2     160000
# 3     135000
# 4     124000
# ...      ...
# 1454  125500
# 1455  125500
# 1456  160000
# 1457  135000
# 1458  197000
#
# [1459 rows x 1 columns]

# %%
ans2=pd.DataFrame(imputer_testdf['Id'])

# %%
ans2=pd.concat([ans2,pred2],axis=1)

# %%
ans2.columns=['Id','SalePrice']

# %%
ans2
# Out:
#         Id  SalePrice
# 0     1461     145000
# 1     1462     151500
# 2     1463     160000
# 3     1464     135000
# 4     1465     124000
# ...    ...        ...
# 1454  2915     125500
# 1455  2916     125500
# 1456  2917     160000
# 1457  2918     135000
# 1458  2919     197000
#
# [1459 rows x 2 columns]

# %%
finals=ans2.to_csv('secondsol.csv',index=False)
